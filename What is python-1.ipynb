# %% [markdown]
# # $\color{blue}{\text{Python}}$

# %% [markdown]
# ## What is Python

# %% [markdown]
# According to the definiton of *Python.org*, Python is an interpreted, object-oriented, high-level programming language with dynamic semantics. Its high-level built in data structures, combined with dynamic typing and dynamic binding, make it very attractive for Rapid Application Development, as well as for use as a scripting or glue language to connect existing components together.

# %% [markdown]
# ## Uses of Python

# %% [markdown]
# Python is often used as a support language for software developers, for build control and management, testing, and in many other ways.
# (python.org)

# %% [markdown]
# ## Why Python is best

# %% [markdown]
# Python is one of the most user-friendly programming languages since it has a simple syntax and isn't overly complex, putting more of an emphasis on natural language. Python is simpler to learn and use than other programming languages, making it easier to write and execute codes.

# %% [markdown]
# ## $\color{g}{\text{How to start Python}}$

# %% [markdown]
# It needs to use some Integrated Development Environment (IDE) to start python coding. Here I will use *Jupyter notebook*

# %% [markdown]
# **Jupyter Notebook** is a web-based program to code Python for scientific purposes in Anaconda.

# %% [markdown]
# **Anaconda** is a Python distribution with many software tools in it. Its environment looks like..

# %% [markdown]
# ![anacondaImage.PNG](attachment:anacondaImage.PNG)

# %% [markdown]
# Anaconda can be installed from [here](Anaconda.com/downloads)

# %% [markdown]
# After completing installation with all the given instruction, just luch **Jupyter Notebook**

# %% [markdown]
# After opening Jupyter Notebook you will get the following environment.

# %% [markdown]
# ![jyp.img0.PNG](attachment:jyp.img0.PNG)

# %% [markdown]
# ![jyp.img1.PNG](attachment:jyp.img1.PNG)

# %% [markdown]
# - The rectangular box {In[]} with static cursor is called a **Cell**, where text can be written.
# - The yellow marked box shows the cell type. On click on the corner downward arrow the menu can be selected.
# - After writing code in the cell, it can be run by pressing **Run** button, which is marked with red circle.
# - The text on the top marked with black circle, is the name of the open Jupyter file. It can be changed by clicking on it.

# %% [markdown]
# #### Writing a code and runing it, it will give output like.
#  The cell mode should be **Code**

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# It is a simple command we can run.

# %% [markdown]
# #### Performing Mathematical Operations

# %%
x = 2 + 5

# %% [markdown]
# In the above cell 'x' is called variable and '=' is called assigning operator. 2 and 5 will addup and the result will store in variable x. The result can be displayed

# %%
x
# Out:
# 7

# %% [markdown]
# ### Basic concept of Programming

# %% [markdown]
# - **CODING** is the process of writting a commands to instruct the computer to perform various task.
# - **Instructions** are the commands which are given to the computer in specific manner to make required action.

# %% [markdown]
# In programing DATA is handled, and perfomed various operations on it. It is important to know the types of data or **Data Type** in python.

# %% [markdown]
# ###  Python Data Types

# %% [markdown]
# - 1)   Numeric
# - 2)    Strings
# - 3) Tuple
# - 4) List
# - 5) Set
# - 6) Dictionary

# %% [markdown]
# The above data types and some essential opetations will further discussed on next repository.

# %% [markdown]
# ###                                                     Thank You
